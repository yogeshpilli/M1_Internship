# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas import concat
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import LabelEncoder
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers.recurrent import LSTM
from keras.layers.core import Dense, Activation, Dropout
from keras.layers import Dense, Dropout
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
from sklearn.metrics import *
# Out:
# Using TensorFlow backend.

# %%
data =pd.read_csv("/content/drive/My Drive/Reddit_brexit_period5.csv")
data.head()
# Out:
#    Unnamed: 0  periods  ... polarization_class      Date
# 0       14183        5  ...            Neutral  27-01-17
# 1       14184        5  ...            Neutral  27-01-17
# 2       14185        5  ...             Brexit  27-01-17
# 3       14186        5  ...            Neutral  27-01-17
# 4       14187        5  ...            Against  27-01-17
#
# [5 rows x 11 columns]

# %%
from sklearn.preprocessing import LabelEncoder

lb_make = LabelEncoder()
data["Stance"] = lb_make.fit_transform(data["polarization_class"])
data[["polarization_class", "Stance"]].head(10)
# Out:
#   polarization_class  Stance
# 0            Neutral       2
# 1            Neutral       2
# 2             Brexit       1
# 3            Neutral       2
# 4            Against       0
# 5             Brexit       1
# 6             Brexit       1
# 7             Brexit       1
# 8            Against       0
# 9            Against       0

# %%
data_to_use = data['Stance'].values
data['polarization_class'].value_counts()
# Out:
# Neutral    970
# Against    789
# Brexit     541
# Name: polarization_class, dtype: int64

# %%
# create X/y pairs
df = data['Stance']
df = concat([df, df.shift(1)], axis=1)
df.dropna(inplace=True)

# %%
values = df.values
y1 = values[:, 1]

# %%
#data preprocessing(scaling)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(values[:,0].reshape(-1, 1))
print(scaled_data)
scaled_data.shape
# Out:
# [[ 1.05827813]
#  [-0.08989621]
#  [ 1.05827813]
#  ...
#  [ 1.05827813]
#  [-1.23807054]
#  [ 1.05827813]]
# (2299, 1)

# %%
#y1 = to_categorical(y1)
#y1.shape
#labels = to_categorical(data['LABEL'], num_classes=3)
#do this instead of above
encoder = LabelEncoder()
labels = to_categorical(encoder.fit_transform(values[:, 1]), num_classes=3)

# %%
labels.shape
# Out:
# (2299, 3)

# %%
X_Train, X_Test, y_Train, y_Test = train_test_split(scaled_data,labels, test_size=0.20, random_state=42)

# %%
print(" X Training Set size is",X_Train.shape )
print(" y Training Set size is",y_Train.shape  )
print(" X Test Set size is",X_Test.shape)
print(" y Test Set size is",y_Test.shape )
# Out:
#  X Training Set size is (1839, 1)
#  y Training Set size is (1839, 3)
#  X Test Set size is (460, 1)
#  y Test Set size is (460, 3)

# %%
# convert to LSTM friendly format
X_Train = X_Train.reshape(len(X_Train),1, 1)
X_Test = X_Test.reshape(len(X_Test),1,1)
print(X_Train.shape,X_Test.shape)
# Out:
# (1839, 1, 1) (460, 1, 1)

# %%
scaled_data = scaled_data.reshape(len(scaled_data),1,1)

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
Y_reg = values[:, 1]
X= scaled_data

# %%
from keras.optimizers import SGD, adam, rmsprop
opt = SGD(lr=0.1)
opt_alpha2 = rmsprop(lr =0.0001)
opt_alpha1 = adam(lr=0.01)

# %%
#cross validation -- beware lasts long
cvscores = []
loss_vals = []
val_accs = []
for train, test in kfold.split(X, Y_reg):
  #Turn labels into categorical after the split
  encoder = LabelEncoder()
  Y = to_categorical(encoder.fit_transform(Y_reg), num_classes=3)
  #define the model
  model = Sequential()
  model.add(LSTM(100, dropout=0.5, recurrent_dropout=0.5))
  model.add(Dense(3, activation='softmax'))
  model.compile(loss='categorical_hinge', optimizer= 'adam', metrics=['accuracy'])
  
  #fit the model
  history = model.fit(X[train], Y[train], validation_data=(X[test], Y[test]), epochs=5, batch_size=256)
  #predict
  score = model.evaluate(X[test], Y[test], verbose=0)
  #store values
  loss_vals.append(history.history['val_loss'])
  val_accs.append(history.history['val_accuracy'])
  cvscores.append(score[1])
model.summary()
# Out:
# Train on 1839 samples, validate on 460 samples
# Epoch 1/5
# 1839/1839 [==============================] - 1s 460us/step - loss: 1.0079 - accuracy: 0.3540 - val_loss: 1.0036 - val_accuracy: 0.4217
# Epoch 2/5
# 1839/1839 [==============================] - 0s 38us/step - loss: 1.0029 - accuracy: 0.3893 - val_loss: 1.0009 - val_accuracy: 0.3435
# Epoch 3/5
# 1839/1839 [==============================] - 0s 37us/step - loss: 1.0015 - accuracy: 0.3573 - val_loss: 1.0026 - val_accuracy: 0.3435
# Epoch 4/5
# 1839/1839 [==============================] - 0s 37us/step - loss: 1.0016 - accuracy: 0.4144 - val_loss: 1.0010 - val_accuracy: 0.3848
# Epoch 5/5
# 1839/1839 [==============================] - 0s 38us/step - loss: 1.0008 - accuracy: 0.3622 - val_loss: 1.0004 - val_accuracy: 0.4217
# Train on 1839 samples, validate on 460 samples
# Epoch 1/5
# 1839/1839 [==============================] - 1s 299us/step - loss: 1.0046 - accuracy: 0.3910 - val_loss: 1.0012 - val_accuracy: 0.4239
# Epoch 2/5
# 1839/1839 [==============================] - 0s 37us/step - loss: 1.0013 - accuracy: 0.3344 - val_loss: 1.0011 - val_accuracy: 0.3804
# Epoch 3/5
# 1839/1839 [==============================] - 0s 38us/step - loss: 1.0010 - accuracy: 0.4067 - val_loss: 1.0003 - val_accuracy: 0.3804
# Epoch 4/5
# 1839/1839 [==============================] - 0s 43us/step - loss: 1.0004 - accuracy: 0.3616 - val_loss: 1.0001 - val_accuracy: 0.3804
# Epoch 5/5
# 1839/1839 [==============================] - 0s 37us/step - loss: 1.0002 - accuracy: 0.3850 - val_loss: 1.0002 - val_accuracy: 0.4239
# Train on 1839 samples, validate on 460 samples
# Epoch 1/5
# 1839/1839 [==============================] - 1s 278us/step - loss: 1.0014 - accuracy: 0.3719 - val_loss: 1.0006 - val_accuracy: 0.3609
# Epoch 2/5
# 1839/1839 [==============================] - 0s 36us/step - loss: 1.0007 - accuracy: 0.4046 - val_loss: 1.0004 - val_accuracy: 0.4043
# Epoch 3/5
# 1839/1839 [==============================] - 0s 39us/step - loss: 1.0004 - accuracy: 0.3556 - val_loss: 1.0003 - val_accuracy: 0.4217
# Epoch 4/5
# 1839/1839 [==============================] - 0s 37us/step - loss: 1.0004 - accuracy: 0.4035 - val_loss: 1.0000 - val_accuracy: 0.4043
# Epoch 5/5
# 1839/1839 [==============================] - 0s 38us/step - loss: 1.0002 - accuracy: 0.3507 - val_loss: 1.0001 - val_accuracy: 0.4217
# Train on 1839 samples, validate on 460 samples
# Epoch 1/5
# 1839/1839 [==============================] - 1s 276us/step - loss: 1.0029 - accuracy: 0.3888 - val_loss: 1.0006 - val_accuracy: 0.3630
# Epoch 2/5
# 1839/1839 [==============================] - 0s 37us/step - loss: 1.0009 - accuracy: 0.3757 - val_loss: 1.0008 - val_accuracy: 0.3652
# Epoch 3/5
# 1839/1839 [==============================] - 0s 38us/step - loss: 1.0009 - accuracy: 0.4067 - val_loss: 1.0006 - val_accuracy: 0.4152
# Epoch 4/5
# 1839/1839 [==============================] - 0s 38us/step - loss: 1.0006 - accuracy: 0.3763 - val_loss: 1.0005 - val_accuracy: 0.3500
# Epoch 5/5
# 1839/1839 [==============================] - 0s 35us/step - loss: 1.0005 - accuracy: 0.3839 - val_loss: 1.0002 - val_accuracy: 0.4217
# Train on 1840 samples, validate on 459 samples
# Epoch 1/5
# 1840/1840 [==============================] - 0s 267us/step - loss: 1.0041 - accuracy: 0.3717 - val_loss: 1.0017 - val_accuracy: 0.3595
# Epoch 2/5
# 1840/1840 [==============================] - 0s 37us/step - loss: 1.0009 - accuracy: 0.3908 - val_loss: 1.0011 - val_accuracy: 0.3246
# Epoch 3/5
# 1840/1840 [==============================] - 0s 46us/step - loss: 1.0007 - accuracy: 0.3951 - val_loss: 1.0005 - val_accuracy: 0.3595
# Epoch 4/5
# 1840/1840 [==============================] - 0s 36us/step - loss: 1.0005 - accuracy: 0.3533 - val_loss: 1.0003 - val_accuracy: 0.4031
# Epoch 5/5
# 1840/1840 [==============================] - 0s 36us/step - loss: 1.0003 - accuracy: 0.3402 - val_loss: 1.0003 - val_accuracy: 0.4205
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_5 (LSTM)                (None, 100)               40800
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 41,103
# Trainable params: 41,103
# Non-trainable params: 0
# _________________________________________________________________

# %%
#define the model
model = Sequential()
model.build(input_shape= (1, X_Train.shape[1], X_Train.shape[2]) )
model.add(LSTM(100, dropout=0.5, recurrent_dropout=0.5))
model.add(Dense(3, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=opt,metrics = ['accuracy'])
model.summary()
#fit
history = model.fit(X_Train, y_Train, validation_data=(X_Test, y_Test), epochs=5, batch_size=1)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_6 (LSTM)                (1, 100)                  40800
# _________________________________________________________________
# dense_6 (Dense)              (1, 3)                    303
# =================================================================
# Total params: 41,103
# Trainable params: 41,103
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1839 samples, validate on 460 samples
# Epoch 1/5
# 1839/1839 [==============================] - 4s 2ms/step - loss: 1.0982 - accuracy: 0.3779 - val_loss: 1.0685 - val_accuracy: 0.4543
# Epoch 2/5
# 1839/1839 [==============================] - 3s 2ms/step - loss: 1.0926 - accuracy: 0.3904 - val_loss: 1.0539 - val_accuracy: 0.4543
# Epoch 3/5
# 1839/1839 [==============================] - 3s 2ms/step - loss: 1.0957 - accuracy: 0.3915 - val_loss: 1.0602 - val_accuracy: 0.4543
# Epoch 4/5
# 1839/1839 [==============================] - 4s 2ms/step - loss: 1.0929 - accuracy: 0.3926 - val_loss: 1.0652 - val_accuracy: 0.4543
# Epoch 5/5
# 1839/1839 [==============================] - 4s 2ms/step - loss: 1.0901 - accuracy: 0.3937 - val_loss: 1.0687 - val_accuracy: 0.4543

# %%
def plot_history(history):
    history_dict = history.history

    loss_values = history_dict['loss']
    val_loss_values = history_dict['val_loss']
    acc = history_dict['accuracy']
    val_acc = history_dict['val_accuracy']

    epochs = [i + 1 for i in history.epoch]

    # Plot the results
    plt.figure(figsize=(12, 3.8))
    plt.subplot(121)
    plt.plot(epochs, loss_values, 'b-', label='Training loss')
    plt.plot(epochs, val_loss_values, 'b.-', label='Val loss')
    plt.xlabel('Epochs', fontsize=12)
    plt.xticks(epochs)
    plt.ylabel('Loss', fontsize=12)
    plt.legend(fontsize=14)
    plt.title('Training and validation loss', fontsize=16)

    plt.subplot(122)
    plt.plot(epochs, acc, 'b-', label='Training accuracy')
    plt.plot(epochs, val_acc, 'b.-', label='Val accuracy')
    plt.xlabel('Epochs', fontsize=12)
    plt.xticks(epochs)
    plt.ylabel('Acc', fontsize=12)
    plt.legend(fontsize=14)
    plt.title('Training and validation acc', fontsize=16)

    plt.show()

# %%
plot_history(history)

# %%
# evaluate the model
_, train_acc = model.evaluate(X_Train, y_Train, verbose=0)
_, test_acc = model.evaluate(X_Test, y_Test, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Train: 0.413, Test: 0.454

# %%
# predict probabilities for test set
yhat_probs = model.predict(X_Test, verbose=0)
# predict crisp classes for test set
yhat_classes = model.predict_classes(X_Test, verbose=0)

# %%
yhat_probs[0:5]
# Out:
# array([[0.26561677, 0.25910848, 0.4752747 ],
#        [0.26561677, 0.25910848, 0.4752747 ],
#        [0.26561677, 0.25910848, 0.4752747 ],
#        [0.26561677, 0.25910848, 0.4752747 ],
#        [0.26561677, 0.25910848, 0.4752747 ]], dtype=float32)

# %%
yhat_classes[0:5]
# Out:
# array([2, 2, 2, 2, 2])

# %%
testy_inverse = np.argmax(y_Test, axis=1).reshape(-1,1)

# %%
print(testy_inverse.shape)
y_Test = testy_inverse[:, 0]
y_Test.shape
# Out:
# (460, 1)
# (460,)

# %%
# reduce to 1d array
yhat_probs = yhat_probs[:, 0]

# %%
# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_Test, yhat_classes)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(y_Test, yhat_classes,pos_label='positive',average='micro')
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_Test, yhat_classes,pos_label='positive',average='micro')
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_Test, yhat_classes,pos_label='positive',average='micro')
print('F1 score: %f' % f1)
# Out:
# Accuracy: 0.454348
# Precision: 0.454348
# Recall: 0.454348
# F1 score: 0.454348
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1321: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   % (pos_label, average), UserWarning)

# %%
# confusion matrix
matrix = confusion_matrix(y_Test, yhat_classes)
print(matrix)
# Out:
# [[  0   0 152]
#  [  0   0  99]
#  [  0   0 209]]

# %%
y_Test.shape,yhat_classes.shape
# Out:
# ((460,), (460,))

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_Test,yhat_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       152
#            1       0.00      0.00      0.00        99
#            2       0.45      1.00      0.62       209
#
#     accuracy                           0.45       460
#    macro avg       0.15      0.33      0.21       460
# weighted avg       0.21      0.45      0.28       460
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
