# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas import concat
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import LabelEncoder
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers.recurrent import LSTM
from keras.layers.core import Dense, Activation, Dropout
from keras.layers import Dense, Dropout
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
from sklearn.metrics import *
# Out:
# Using TensorFlow backend.

# %%
data =pd.read_csv("/content/drive/My Drive/Reddit_brexit_period12.csv")
data.head()
# Out:
#    Unnamed: 0  periods  ... polarization_class      Date
# 0      142728       12  ...            Neutral  16-01-19
# 1      142729       12  ...             Brexit  16-01-19
# 2      142730       12  ...             Brexit  16-01-19
# 3      142731       12  ...            Neutral  16-01-19
# 4      142732       12  ...             Brexit  16-01-19
#
# [5 rows x 11 columns]

# %%
from sklearn.preprocessing import LabelEncoder

lb_make = LabelEncoder()
data["Stance"] = lb_make.fit_transform(data["polarization_class"])
data[["polarization_class", "Stance"]].head(10)
# Out:
#   polarization_class  Stance
# 0            Neutral       2
# 1             Brexit       1
# 2             Brexit       1
# 3            Neutral       2
# 4             Brexit       1
# 5             Brexit       1
# 6             Brexit       1
# 7             Brexit       1
# 8            Against       0
# 9             Brexit       1

# %%
data_to_use = data['Stance'].values
data['polarization_class'].value_counts()
# Out:
# Neutral    24041
# Against    15449
# Brexit     15360
# Name: polarization_class, dtype: int64

# %%
# create X/y pairs
df = data['Stance']
df = concat([df, df.shift(1)], axis=1)
df.dropna(inplace=True)

# %%
values = df.values
y1 = values[:, 1]

# %%
#data preprocessing(scaling)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(values[:,0].reshape(-1, 1))
print(scaled_data)
scaled_data.shape
# Out:
# [[-0.1878234 ]
#  [-0.1878234 ]
#  [ 1.01132989]
#  ...
#  [ 1.01132989]
#  [-0.1878234 ]
#  [ 1.01132989]]
# (54849, 1)

# %%
#y1 = to_categorical(y1)
#y1.shape
#labels = to_categorical(data['LABEL'], num_classes=3)
#do this instead of above
encoder = LabelEncoder()
labels = to_categorical(encoder.fit_transform(values[:, 1]), num_classes=3)

# %%
labels.shape
# Out:
# (54849, 3)

# %%
X_Train, X_Test, y_Train, y_Test = train_test_split(scaled_data,labels, test_size=0.20, random_state=42)

# %%
print(" X Training Set size is",X_Train.shape )
print(" y Training Set size is",y_Train.shape  )
print(" X Test Set size is",X_Test.shape)
print(" y Test Set size is",y_Test.shape )
# Out:
#  X Training Set size is (43879, 1)
#  y Training Set size is (43879, 3)
#  X Test Set size is (10970, 1)
#  y Test Set size is (10970, 3)

# %%
# convert to LSTM friendly format
X_Train = X_Train.reshape(len(X_Train),1, 1)
X_Test = X_Test.reshape(len(X_Test),1,1)
print(X_Train.shape,X_Test.shape)
# Out:
# (43879, 1, 1) (10970, 1, 1)

# %%
scaled_data = scaled_data.reshape(len(scaled_data),1,1)

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
Y_reg = values[:, 1]
X= scaled_data

# %%
from keras.optimizers import SGD, adam, rmsprop
opt = SGD(lr=0.1)
opt_alpha2 = rmsprop(lr =0.0001)
opt_alpha1 = adam(lr=0.01)

# %%
#cross validation -- beware lasts long
cvscores = []
loss_vals = []
val_accs = []
for train, test in kfold.split(X, Y_reg):
  #Turn labels into categorical after the split
  encoder = LabelEncoder()
  Y = to_categorical(encoder.fit_transform(Y_reg), num_classes=3)
  #define the model
  model = Sequential()
  model.add(LSTM(100, dropout=0.5, recurrent_dropout=0.5))
  model.add(Dense(3, activation='softmax'))
  model.compile(loss='categorical_hinge', optimizer= 'adam', metrics=['accuracy'])
  
  #fit the model
  history = model.fit(X[train], Y[train], validation_data=(X[test], Y[test]), epochs=5, batch_size=256)
  #predict
  score = model.evaluate(X[test], Y[test], verbose=0)
  #store values
  loss_vals.append(history.history['val_loss'])
  val_accs.append(history.history['val_accuracy'])
  cvscores.append(score[1])
model.summary()
# Out:
# Train on 43879 samples, validate on 10970 samples
# Epoch 1/5
# 43879/43879 [==============================] - 2s 45us/step - loss: 1.0004 - accuracy: 0.3906 - val_loss: 1.0002 - val_accuracy: 0.4383
# Epoch 2/5
# 43879/43879 [==============================] - 1s 29us/step - loss: 1.0001 - accuracy: 0.3875 - val_loss: 1.0001 - val_accuracy: 0.3633
# Epoch 3/5
# 43879/43879 [==============================] - 1s 29us/step - loss: 1.0002 - accuracy: 0.3899 - val_loss: 1.0001 - val_accuracy: 0.4383
# Epoch 4/5
# 43879/43879 [==============================] - 1s 30us/step - loss: 1.0002 - accuracy: 0.3797 - val_loss: 1.0002 - val_accuracy: 0.3667
# Epoch 5/5
# 43879/43879 [==============================] - 1s 30us/step - loss: 1.0002 - accuracy: 0.3934 - val_loss: 1.0002 - val_accuracy: 0.3532
# Train on 43879 samples, validate on 10970 samples
# Epoch 1/5
# 43879/43879 [==============================] - 2s 39us/step - loss: 1.0006 - accuracy: 0.3933 - val_loss: 1.0001 - val_accuracy: 0.3500
# Epoch 2/5
# 43879/43879 [==============================] - 1s 29us/step - loss: 1.0001 - accuracy: 0.3892 - val_loss: 1.0001 - val_accuracy: 0.3956
# Epoch 3/5
# 43879/43879 [==============================] - 1s 30us/step - loss: 1.0002 - accuracy: 0.3911 - val_loss: 1.0003 - val_accuracy: 0.3956
# Epoch 4/5
# 43879/43879 [==============================] - 1s 30us/step - loss: 1.0001 - accuracy: 0.3940 - val_loss: 1.0001 - val_accuracy: 0.3705
# Epoch 5/5
# 43879/43879 [==============================] - 1s 30us/step - loss: 1.0001 - accuracy: 0.3870 - val_loss: 1.0001 - val_accuracy: 0.3479
# Train on 43879 samples, validate on 10970 samples
# Epoch 1/5
# 43879/43879 [==============================] - 2s 40us/step - loss: 1.0006 - accuracy: 0.3887 - val_loss: 1.0002 - val_accuracy: 0.2817
# Epoch 2/5
# 43879/43879 [==============================] - 1s 27us/step - loss: 1.0001 - accuracy: 0.3882 - val_loss: 1.0002 - val_accuracy: 0.3924
# Epoch 3/5
# 43879/43879 [==============================] - 1s 28us/step - loss: 1.0001 - accuracy: 0.3909 - val_loss: 1.0001 - val_accuracy: 0.4383
# Epoch 4/5
# 43879/43879 [==============================] - 1s 28us/step - loss: 1.0002 - accuracy: 0.3928 - val_loss: 1.0002 - val_accuracy: 0.3924
# Epoch 5/5
# 43879/43879 [==============================] - 1s 29us/step - loss: 1.0002 - accuracy: 0.3880 - val_loss: 1.0002 - val_accuracy: 0.2811
# Train on 43879 samples, validate on 10970 samples
# Epoch 1/5
# 43879/43879 [==============================] - 2s 38us/step - loss: 1.0003 - accuracy: 0.3874 - val_loss: 1.0002 - val_accuracy: 0.2799
# Epoch 2/5
# 43879/43879 [==============================] - 1s 30us/step - loss: 1.0002 - accuracy: 0.3879 - val_loss: 1.0002 - val_accuracy: 0.3308
# Epoch 3/5
# 43879/43879 [==============================] - 1s 28us/step - loss: 1.0001 - accuracy: 0.3927 - val_loss: 1.0003 - val_accuracy: 0.2817
# Epoch 4/5
# 43879/43879 [==============================] - 1s 30us/step - loss: 1.0002 - accuracy: 0.3917 - val_loss: 1.0001 - val_accuracy: 0.3715
# Epoch 5/5
# 43879/43879 [==============================] - 1s 30us/step - loss: 1.0002 - accuracy: 0.3850 - val_loss: 1.0001 - val_accuracy: 0.2747
# Train on 43880 samples, validate on 10969 samples
# Epoch 1/5
# 43880/43880 [==============================] - 2s 36us/step - loss: 1.0004 - accuracy: 0.3867 - val_loss: 1.0001 - val_accuracy: 0.3496
# Epoch 2/5
# 43880/43880 [==============================] - 1s 28us/step - loss: 1.0002 - accuracy: 0.3835 - val_loss: 1.0002 - val_accuracy: 0.3494
# Epoch 3/5
# 43880/43880 [==============================] - 1s 30us/step - loss: 1.0002 - accuracy: 0.3845 - val_loss: 1.0001 - val_accuracy: 0.4383
# Epoch 4/5
# 43880/43880 [==============================] - 1s 29us/step - loss: 1.0002 - accuracy: 0.3869 - val_loss: 1.0001 - val_accuracy: 0.4383
# Epoch 5/5
# 43880/43880 [==============================] - 1s 29us/step - loss: 1.0001 - accuracy: 0.3884 - val_loss: 1.0001 - val_accuracy: 0.2816
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_5 (LSTM)                (None, 100)               40800
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 41,103
# Trainable params: 41,103
# Non-trainable params: 0
# _________________________________________________________________

# %%
#define the model
model = Sequential()
model.build(input_shape= (1, X_Train.shape[1], X_Train.shape[2]) )
model.add(LSTM(100, dropout=0.5, recurrent_dropout=0.5))
model.add(Dense(3, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=opt,metrics = ['accuracy'])
model.summary()
#fit
history = model.fit(X_Train, y_Train, validation_data=(X_Test, y_Test), epochs=5, batch_size=1)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_6 (LSTM)                (1, 100)                  40800
# _________________________________________________________________
# dense_6 (Dense)              (1, 3)                    303
# =================================================================
# Total params: 41,103
# Trainable params: 41,103
# Non-trainable params: 0
# _________________________________________________________________
# Train on 43879 samples, validate on 10970 samples
# Epoch 1/5
# 43879/43879 [==============================] - 74s 2ms/step - loss: 1.0925 - accuracy: 0.4163 - val_loss: 1.0777 - val_accuracy: 0.4392
# Epoch 2/5
# 43879/43879 [==============================] - 74s 2ms/step - loss: 1.0915 - accuracy: 0.4186 - val_loss: 1.0778 - val_accuracy: 0.4392
# Epoch 3/5
# 43879/43879 [==============================] - 75s 2ms/step - loss: 1.0918 - accuracy: 0.4159 - val_loss: 1.0986 - val_accuracy: 0.4392
# Epoch 4/5
# 43879/43879 [==============================] - 74s 2ms/step - loss: 1.0922 - accuracy: 0.4145 - val_loss: 1.0798 - val_accuracy: 0.4392
# Epoch 5/5
# 43879/43879 [==============================] - 75s 2ms/step - loss: 1.0913 - accuracy: 0.4153 - val_loss: 1.0776 - val_accuracy: 0.4392

# %%
def plot_history(history):
    history_dict = history.history

    loss_values = history_dict['loss']
    val_loss_values = history_dict['val_loss']
    acc = history_dict['accuracy']
    val_acc = history_dict['val_accuracy']

    epochs = [i + 1 for i in history.epoch]

    # Plot the results
    plt.figure(figsize=(12, 3.8))
    plt.subplot(121)
    plt.plot(epochs, loss_values, 'b-', label='Training loss')
    plt.plot(epochs, val_loss_values, 'b.-', label='Val loss')
    plt.xlabel('Epochs', fontsize=12)
    plt.xticks(epochs)
    plt.ylabel('Loss', fontsize=12)
    plt.legend(fontsize=14)
    plt.title('Training and validation loss', fontsize=16)

    plt.subplot(122)
    plt.plot(epochs, acc, 'b-', label='Training accuracy')
    plt.plot(epochs, val_acc, 'b.-', label='Val accuracy')
    plt.xlabel('Epochs', fontsize=12)
    plt.xticks(epochs)
    plt.ylabel('Acc', fontsize=12)
    plt.legend(fontsize=14)
    plt.title('Training and validation acc', fontsize=16)

    plt.show()

# %%
plot_history(history)

# %%
# evaluate the model
_, train_acc = model.evaluate(X_Train, y_Train, verbose=0)
_, test_acc = model.evaluate(X_Test, y_Test, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Train: 0.438, Test: 0.439

# %%
# predict probabilities for test set
yhat_probs = model.predict(X_Test, verbose=0)
# predict crisp classes for test set
yhat_classes = model.predict_classes(X_Test, verbose=0)

# %%
yhat_probs[0:5]
# Out:
# array([[0.27265996, 0.2503168 , 0.47702327],
#        [0.27265996, 0.2503168 , 0.47702327],
#        [0.27265996, 0.2503168 , 0.47702327],
#        [0.27265996, 0.2503168 , 0.47702327],
#        [0.27265996, 0.2503168 , 0.47702327]], dtype=float32)

# %%
yhat_classes[0:5]
# Out:
# array([2, 2, 2, 2, 2])

# %%
testy_inverse = np.argmax(y_Test, axis=1).reshape(-1,1)

# %%
print(testy_inverse.shape)
y_Test = testy_inverse[:, 0]
y_Test.shape
# Out:
# (10970, 1)
# (10970,)

# %%
# reduce to 1d array
yhat_probs = yhat_probs[:, 0]

# %%
# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_Test, yhat_classes)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(y_Test, yhat_classes,pos_label='positive',average='micro')
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_Test, yhat_classes,pos_label='positive',average='micro')
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_Test, yhat_classes,pos_label='positive',average='micro')
print('F1 score: %f' % f1)
# Out:
# Accuracy: 0.439198
# Precision: 0.439198
# Recall: 0.439198
# F1 score: 0.439198
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1321: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   % (pos_label, average), UserWarning)

# %%
# confusion matrix
matrix = confusion_matrix(y_Test, yhat_classes)
print(matrix)
# Out:
# [[   0    0 3101]
#  [   0    0 3051]
#  [   0    0 4818]]

# %%
y_Test.shape,yhat_classes.shape
# Out:
# ((10970,), (10970,))

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_Test,yhat_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      3101
#            1       0.00      0.00      0.00      3051
#            2       0.44      1.00      0.61      4818
#
#     accuracy                           0.44     10970
#    macro avg       0.15      0.33      0.20     10970
# weighted avg       0.19      0.44      0.27     10970
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
