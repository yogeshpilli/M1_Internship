# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas import concat
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import LabelEncoder
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers.recurrent import LSTM
from keras.layers.core import Dense, Activation, Dropout
from keras.layers import Dense, Dropout
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
from sklearn.metrics import *
# Out:
# Using TensorFlow backend.

# %%
data =pd.read_csv("/content/drive/My Drive/Reddit_brexit_period2.csv")
data.head()
# Out:
#    Unnamed: 0  periods  ... polarization_class      Date
# 0        3368        2  ...            Against  25-06-16
# 1        3369        2  ...             Brexit  25-06-16
# 2        3370        2  ...             Brexit  25-06-16
# 3        3371        2  ...            Against  25-06-16
# 4        3372        2  ...             Brexit  25-06-16
#
# [5 rows x 11 columns]

# %%
from sklearn.preprocessing import LabelEncoder

lb_make = LabelEncoder()
data["Stance"] = lb_make.fit_transform(data["polarization_class"])
data[["polarization_class", "Stance"]].head(10)
# Out:
#   polarization_class  Stance
# 0            Against       0
# 1             Brexit       1
# 2             Brexit       1
# 3            Against       0
# 4             Brexit       1
# 5             Brexit       1
# 6            Neutral       2
# 7            Against       0
# 8             Brexit       1
# 9            Against       0

# %%
data_to_use = data['Stance'].values
data['polarization_class'].value_counts()
# Out:
# Neutral    2364
# Brexit     2067
# Against    1834
# Name: polarization_class, dtype: int64

# %%
# create X/y pairs
df = data['Stance']
df = concat([df, df.shift(1)], axis=1)
df.dropna(inplace=True)

# %%
values = df.values
y1 = values[:, 1]

# %%
#data preprocessing(scaling)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(values[:,0].reshape(-1, 1))
print(scaled_data)
scaled_data.shape
# Out:
# [[-0.10412156]
#  [-0.10412156]
#  [-1.33240296]
#  ...
#  [-1.33240296]
#  [ 1.12415985]
#  [-0.10412156]]
# (6264, 1)

# %%
#y1 = to_categorical(y1)
#y1.shape
#labels = to_categorical(data['LABEL'], num_classes=3)
#do this instead of above
encoder = LabelEncoder()
labels = to_categorical(encoder.fit_transform(values[:, 1]), num_classes=3)

# %%
labels.shape
# Out:
# (6264, 3)

# %%
X_Train, X_Test, y_Train, y_Test = train_test_split(scaled_data,labels, test_size=0.20, random_state=42)

# %%
print(" X Training Set size is",X_Train.shape )
print(" y Training Set size is",y_Train.shape  )
print(" X Test Set size is",X_Test.shape)
print(" y Test Set size is",y_Test.shape )
# Out:
#  X Training Set size is (5011, 1)
#  y Training Set size is (5011, 3)
#  X Test Set size is (1253, 1)
#  y Test Set size is (1253, 3)

# %%
# convert to LSTM friendly format
X_Train = X_Train.reshape(len(X_Train),1, 1)
X_Test = X_Test.reshape(len(X_Test),1,1)
print(X_Train.shape,X_Test.shape)
# Out:
# (5011, 1, 1) (1253, 1, 1)

# %%
scaled_data = scaled_data.reshape(len(scaled_data),1,1)

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
Y_reg = values[:, 1]
X= scaled_data

# %%
from keras.optimizers import SGD, adam, rmsprop
opt = SGD(lr=0.1)
opt_alpha2 = rmsprop(lr =0.0001)
opt_alpha1 = adam(lr=0.01)

# %%
#cross validation -- beware lasts long
cvscores = []
loss_vals = []
val_accs = []
for train, test in kfold.split(X, Y_reg):
  #Turn labels into categorical after the split
  encoder = LabelEncoder()
  Y = to_categorical(encoder.fit_transform(Y_reg), num_classes=3)
  #define the model
  model = Sequential()
  model.add(LSTM(100, dropout=0.5, recurrent_dropout=0.5))
  model.add(Dense(3, activation='softmax'))
  model.compile(loss='categorical_hinge', optimizer= 'adam', metrics=['accuracy'])
  
  #fit the model
  history = model.fit(X[train], Y[train], validation_data=(X[test], Y[test]), epochs=5, batch_size=256)
  #predict
  score = model.evaluate(X[test], Y[test], verbose=0)
  #store values
  loss_vals.append(history.history['val_loss'])
  val_accs.append(history.history['val_accuracy'])
  cvscores.append(score[1])
model.summary()
# Out:
# Train on 5011 samples, validate on 1253 samples
# Epoch 1/5
# 5011/5011 [==============================] - 1s 199us/step - loss: 1.0007 - accuracy: 0.3506 - val_loss: 1.0004 - val_accuracy: 0.3456
# Epoch 2/5
# 5011/5011 [==============================] - 0s 36us/step - loss: 1.0003 - accuracy: 0.3315 - val_loss: 1.0002 - val_accuracy: 0.3575
# Epoch 3/5
# 5011/5011 [==============================] - 0s 34us/step - loss: 1.0002 - accuracy: 0.3522 - val_loss: 1.0000 - val_accuracy: 0.3248
# Epoch 4/5
# 5011/5011 [==============================] - 0s 35us/step - loss: 1.0002 - accuracy: 0.3478 - val_loss: 1.0002 - val_accuracy: 0.3360
# Epoch 5/5
# 5011/5011 [==============================] - 0s 35us/step - loss: 1.0001 - accuracy: 0.3375 - val_loss: 1.0002 - val_accuracy: 0.3543
# Train on 5011 samples, validate on 1253 samples
# Epoch 1/5
# 5011/5011 [==============================] - 1s 121us/step - loss: 1.0009 - accuracy: 0.3409 - val_loss: 1.0005 - val_accuracy: 0.3448
# Epoch 2/5
# 5011/5011 [==============================] - 0s 35us/step - loss: 1.0004 - accuracy: 0.3468 - val_loss: 1.0001 - val_accuracy: 0.3775
# Epoch 3/5
# 5011/5011 [==============================] - 0s 40us/step - loss: 1.0002 - accuracy: 0.3660 - val_loss: 1.0002 - val_accuracy: 0.3296
# Epoch 4/5
# 5011/5011 [==============================] - 0s 36us/step - loss: 1.0002 - accuracy: 0.3315 - val_loss: 1.0002 - val_accuracy: 0.3121
# Epoch 5/5
# 5011/5011 [==============================] - 0s 43us/step - loss: 1.0002 - accuracy: 0.3474 - val_loss: 1.0002 - val_accuracy: 0.3599
# Train on 5011 samples, validate on 1253 samples
# Epoch 1/5
# 5011/5011 [==============================] - 1s 127us/step - loss: 1.0011 - accuracy: 0.3273 - val_loss: 1.0007 - val_accuracy: 0.3017
# Epoch 2/5
# 5011/5011 [==============================] - 0s 35us/step - loss: 1.0004 - accuracy: 0.3520 - val_loss: 1.0003 - val_accuracy: 0.3168
# Epoch 3/5
# 5011/5011 [==============================] - 0s 35us/step - loss: 1.0002 - accuracy: 0.3570 - val_loss: 1.0002 - val_accuracy: 0.3448
# Epoch 4/5
# 5011/5011 [==============================] - 0s 35us/step - loss: 1.0002 - accuracy: 0.3480 - val_loss: 1.0001 - val_accuracy: 0.3448
# Epoch 5/5
# 5011/5011 [==============================] - 0s 36us/step - loss: 1.0001 - accuracy: 0.3387 - val_loss: 1.0001 - val_accuracy: 0.3368
# Train on 5011 samples, validate on 1253 samples
# Epoch 1/5
# 5011/5011 [==============================] - 1s 116us/step - loss: 1.0004 - accuracy: 0.3474 - val_loss: 1.0003 - val_accuracy: 0.3512
# Epoch 2/5
# 5011/5011 [==============================] - 0s 39us/step - loss: 1.0002 - accuracy: 0.3299 - val_loss: 1.0001 - val_accuracy: 0.3328
# Epoch 3/5
# 5011/5011 [==============================] - 0s 38us/step - loss: 1.0002 - accuracy: 0.3472 - val_loss: 1.0001 - val_accuracy: 0.2961
# Epoch 4/5
# 5011/5011 [==============================] - 0s 35us/step - loss: 1.0001 - accuracy: 0.3454 - val_loss: 1.0001 - val_accuracy: 0.2961
# Epoch 5/5
# 5011/5011 [==============================] - 0s 36us/step - loss: 1.0001 - accuracy: 0.3422 - val_loss: 1.0001 - val_accuracy: 0.3512
# Train on 5012 samples, validate on 1252 samples
# Epoch 1/5
# 5012/5012 [==============================] - 1s 130us/step - loss: 1.0011 - accuracy: 0.3430 - val_loss: 1.0003 - val_accuracy: 0.3570
# Epoch 2/5
# 5012/5012 [==============================] - 0s 38us/step - loss: 1.0003 - accuracy: 0.3462 - val_loss: 1.0001 - val_accuracy: 0.3307
# Epoch 3/5
# 5012/5012 [==============================] - 0s 36us/step - loss: 1.0002 - accuracy: 0.3396 - val_loss: 1.0002 - val_accuracy: 0.3099
# Epoch 4/5
# 5012/5012 [==============================] - 0s 36us/step - loss: 1.0002 - accuracy: 0.3322 - val_loss: 1.0001 - val_accuracy: 0.3578
# Epoch 5/5
# 5012/5012 [==============================] - 0s 36us/step - loss: 1.0001 - accuracy: 0.3364 - val_loss: 1.0002 - val_accuracy: 0.3570
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_5 (LSTM)                (None, 100)               40800
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 41,103
# Trainable params: 41,103
# Non-trainable params: 0
# _________________________________________________________________

# %%
#define the model
model = Sequential()
model.build(input_shape= (1, X_Train.shape[1], X_Train.shape[2]) )
model.add(LSTM(100, dropout=0.5, recurrent_dropout=0.5))
model.add(Dense(3, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=opt,metrics = ['accuracy'])
model.summary()
#fit
history = model.fit(X_Train, y_Train, validation_data=(X_Test, y_Test), epochs=5, batch_size=1)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_6 (LSTM)                (1, 100)                  40800
# _________________________________________________________________
# dense_6 (Dense)              (1, 3)                    303
# =================================================================
# Total params: 41,103
# Trainable params: 41,103
# Non-trainable params: 0
# _________________________________________________________________
# Train on 5011 samples, validate on 1253 samples
# Epoch 1/5
# 5011/5011 [==============================] - 9s 2ms/step - loss: 1.1130 - accuracy: 0.3456 - val_loss: 1.1123 - val_accuracy: 0.3743
# Epoch 2/5
# 5011/5011 [==============================] - 10s 2ms/step - loss: 1.1093 - accuracy: 0.3528 - val_loss: 1.1091 - val_accuracy: 0.3743
# Epoch 3/5
# 5011/5011 [==============================] - 9s 2ms/step - loss: 1.1099 - accuracy: 0.3554 - val_loss: 1.0962 - val_accuracy: 0.3743
# Epoch 4/5
# 5011/5011 [==============================] - 9s 2ms/step - loss: 1.1102 - accuracy: 0.3614 - val_loss: 1.0943 - val_accuracy: 0.3743
# Epoch 5/5
# 5011/5011 [==============================] - 9s 2ms/step - loss: 1.1105 - accuracy: 0.3594 - val_loss: 1.0946 - val_accuracy: 0.3408

# %%
def plot_history(history):
    history_dict = history.history

    loss_values = history_dict['loss']
    val_loss_values = history_dict['val_loss']
    acc = history_dict['accuracy']
    val_acc = history_dict['val_accuracy']

    epochs = [i + 1 for i in history.epoch]

    # Plot the results
    plt.figure(figsize=(12, 3.8))
    plt.subplot(121)
    plt.plot(epochs, loss_values, 'b-', label='Training loss')
    plt.plot(epochs, val_loss_values, 'b.-', label='Val loss')
    plt.xlabel('Epochs', fontsize=12)
    plt.xticks(epochs)
    plt.ylabel('Loss', fontsize=12)
    plt.legend(fontsize=14)
    plt.title('Training and validation loss', fontsize=16)

    plt.subplot(122)
    plt.plot(epochs, acc, 'b-', label='Training accuracy')
    plt.plot(epochs, val_acc, 'b.-', label='Val accuracy')
    plt.xlabel('Epochs', fontsize=12)
    plt.xticks(epochs)
    plt.ylabel('Acc', fontsize=12)
    plt.legend(fontsize=14)
    plt.title('Training and validation acc', fontsize=16)

    plt.show()

# %%
plot_history(history)

# %%
# evaluate the model
_, train_acc = model.evaluate(X_Train, y_Train, verbose=0)
_, test_acc = model.evaluate(X_Test, y_Test, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Train: 0.327, Test: 0.341

# %%
# predict probabilities for test set
yhat_probs = model.predict(X_Test, verbose=0)
# predict crisp classes for test set
yhat_classes = model.predict_classes(X_Test, verbose=0)

# %%
yhat_probs[0:5]
# Out:
# array([[0.26602456, 0.37143362, 0.36254182],
#        [0.26602456, 0.37143362, 0.36254182],
#        [0.26602456, 0.37143362, 0.36254182],
#        [0.26602456, 0.37143362, 0.36254182],
#        [0.26602456, 0.37143362, 0.36254182]], dtype=float32)

# %%
yhat_classes[0:5]
# Out:
# array([1, 1, 1, 1, 1])

# %%
testy_inverse = np.argmax(y_Test, axis=1).reshape(-1,1)

# %%
print(testy_inverse.shape)
y_Test = testy_inverse[:, 0]
y_Test.shape
# Out:
# (1253, 1)
# (1253,)

# %%
# reduce to 1d array
yhat_probs = yhat_probs[:, 0]

# %%
# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_Test, yhat_classes)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(y_Test, yhat_classes,pos_label='positive',average='micro')
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_Test, yhat_classes,pos_label='positive',average='micro')
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_Test, yhat_classes,pos_label='positive',average='micro')
print('F1 score: %f' % f1)
# Out:
# Accuracy: 0.340782
# Precision: 0.340782
# Recall: 0.340782
# F1 score: 0.340782
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1321: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   % (pos_label, average), UserWarning)

# %%
# confusion matrix
matrix = confusion_matrix(y_Test, yhat_classes)
print(matrix)
# Out:
# [[  0 357   0]
#  [  0 427   0]
#  [  0 469   0]]

# %%
y_Test.shape,yhat_classes.shape
# Out:
# ((1253,), (1253,))

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_Test,yhat_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       357
#            1       0.34      1.00      0.51       427
#            2       0.00      0.00      0.00       469
#
#     accuracy                           0.34      1253
#    macro avg       0.11      0.33      0.17      1253
# weighted avg       0.12      0.34      0.17      1253
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
