# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas import concat
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import LabelEncoder
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers.recurrent import LSTM
from keras.layers.core import Dense, Activation, Dropout
from keras.layers import Dense, Dropout
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
from sklearn.metrics import *
# Out:
# Using TensorFlow backend.

# %%
data =pd.read_csv("/content/drive/My Drive/Reddit_brexit_period8.csv")
data.head()
# Out:
#    Unnamed: 0  periods  ... polarization_class      Date
# 0       75090        8  ...             Brexit  09-07-18
# 1       75091        8  ...            Neutral  09-07-18
# 2       75092        8  ...            Neutral  09-07-18
# 3       75093        8  ...             Brexit  09-07-18
# 4       75094        8  ...            Neutral  09-07-18
#
# [5 rows x 11 columns]

# %%
from sklearn.preprocessing import LabelEncoder

lb_make = LabelEncoder()
data["Stance"] = lb_make.fit_transform(data["polarization_class"])
data[["polarization_class", "Stance"]].head(10)
# Out:
#   polarization_class  Stance
# 0             Brexit       1
# 1            Neutral       2
# 2            Neutral       2
# 3             Brexit       1
# 4            Neutral       2
# 5             Brexit       1
# 6            Neutral       2
# 7             Brexit       1
# 8            Against       0
# 9            Against       0

# %%
data_to_use = data['Stance'].values
data['polarization_class'].value_counts()
# Out:
# Neutral    10180
# Against     6712
# Brexit      6175
# Name: polarization_class, dtype: int64

# %%
# create X/y pairs
df = data['Stance']
df = concat([df, df.shift(1)], axis=1)
df.dropna(inplace=True)

# %%
values = df.values
y1 = values[:, 1]

# %%
#data preprocessing(scaling)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(values[:,0].reshape(-1, 1))
print(scaled_data)
scaled_data.shape
# Out:
# [[ 1.00854098]
#  [ 1.00854098]
#  [-0.17846822]
#  ...
#  [ 1.00854098]
#  [-1.36547741]
#  [-1.36547741]]
# (23066, 1)

# %%
#y1 = to_categorical(y1)
#y1.shape
#labels = to_categorical(data['LABEL'], num_classes=3)
#do this instead of above
encoder = LabelEncoder()
labels = to_categorical(encoder.fit_transform(values[:, 1]), num_classes=3)

# %%
labels.shape
# Out:
# (23066, 3)

# %%
X_Train, X_Test, y_Train, y_Test = train_test_split(scaled_data,labels, test_size=0.20, random_state=42)

# %%
print(" X Training Set size is",X_Train.shape )
print(" y Training Set size is",y_Train.shape  )
print(" X Test Set size is",X_Test.shape)
print(" y Test Set size is",y_Test.shape )
# Out:
#  X Training Set size is (18452, 1)
#  y Training Set size is (18452, 3)
#  X Test Set size is (4614, 1)
#  y Test Set size is (4614, 3)

# %%
# convert to LSTM friendly format
X_Train = X_Train.reshape(len(X_Train),1, 1)
X_Test = X_Test.reshape(len(X_Test),1,1)
print(X_Train.shape,X_Test.shape)
# Out:
# (18452, 1, 1) (4614, 1, 1)

# %%
scaled_data = scaled_data.reshape(len(scaled_data),1,1)

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
Y_reg = values[:, 1]
X= scaled_data

# %%
from keras.optimizers import SGD, adam, rmsprop
opt = SGD(lr=0.1)
opt_alpha2 = rmsprop(lr =0.0001)
opt_alpha1 = adam(lr=0.01)

# %%
#cross validation -- beware lasts long
cvscores = []
loss_vals = []
val_accs = []
for train, test in kfold.split(X, Y_reg):
  #Turn labels into categorical after the split
  encoder = LabelEncoder()
  Y = to_categorical(encoder.fit_transform(Y_reg), num_classes=3)
  #define the model
  model = Sequential()
  model.add(LSTM(100, dropout=0.5, recurrent_dropout=0.5))
  model.add(Dense(3, activation='softmax'))
  model.compile(loss='categorical_hinge', optimizer= 'adam', metrics=['accuracy'])
  
  #fit the model
  history = model.fit(X[train], Y[train], validation_data=(X[test], Y[test]), epochs=5, batch_size=256)
  #predict
  score = model.evaluate(X[test], Y[test], verbose=0)
  #store values
  loss_vals.append(history.history['val_loss'])
  val_accs.append(history.history['val_accuracy'])
  cvscores.append(score[1])
model.summary()
# Out:
# Train on 18452 samples, validate on 4614 samples
# Epoch 1/5
# 18452/18452 [==============================] - 2s 82us/step - loss: 1.0005 - accuracy: 0.3929 - val_loss: 1.0002 - val_accuracy: 0.3559
# Epoch 2/5
# 18452/18452 [==============================] - 1s 37us/step - loss: 1.0002 - accuracy: 0.3917 - val_loss: 1.0002 - val_accuracy: 0.3916
# Epoch 3/5
# 18452/18452 [==============================] - 1s 39us/step - loss: 1.0002 - accuracy: 0.3984 - val_loss: 1.0003 - val_accuracy: 0.3916
# Epoch 4/5
# 18452/18452 [==============================] - 1s 41us/step - loss: 1.0002 - accuracy: 0.3918 - val_loss: 1.0001 - val_accuracy: 0.4413
# Epoch 5/5
# 18452/18452 [==============================] - 1s 37us/step - loss: 1.0001 - accuracy: 0.4002 - val_loss: 1.0001 - val_accuracy: 0.3765
# Train on 18453 samples, validate on 4613 samples
# Epoch 1/5
# 18453/18453 [==============================] - 1s 70us/step - loss: 1.0004 - accuracy: 0.4003 - val_loss: 1.0003 - val_accuracy: 0.4414
# Epoch 2/5
# 18453/18453 [==============================] - 1s 38us/step - loss: 1.0002 - accuracy: 0.3890 - val_loss: 1.0002 - val_accuracy: 0.3640
# Epoch 3/5
# 18453/18453 [==============================] - 1s 36us/step - loss: 1.0002 - accuracy: 0.3955 - val_loss: 1.0001 - val_accuracy: 0.3859
# Epoch 4/5
# 18453/18453 [==============================] - 1s 35us/step - loss: 1.0001 - accuracy: 0.4049 - val_loss: 1.0001 - val_accuracy: 0.4414
# Epoch 5/5
# 18453/18453 [==============================] - 1s 36us/step - loss: 1.0002 - accuracy: 0.3910 - val_loss: 1.0002 - val_accuracy: 0.4414
# Train on 18453 samples, validate on 4613 samples
# Epoch 1/5
# 18453/18453 [==============================] - 1s 60us/step - loss: 1.0008 - accuracy: 0.3842 - val_loss: 1.0001 - val_accuracy: 0.3722
# Epoch 2/5
# 18453/18453 [==============================] - 1s 35us/step - loss: 1.0002 - accuracy: 0.3976 - val_loss: 1.0002 - val_accuracy: 0.3722
# Epoch 3/5
# 18453/18453 [==============================] - 1s 34us/step - loss: 1.0002 - accuracy: 0.3935 - val_loss: 1.0001 - val_accuracy: 0.3878
# Epoch 4/5
# 18453/18453 [==============================] - 1s 34us/step - loss: 1.0002 - accuracy: 0.3960 - val_loss: 1.0001 - val_accuracy: 0.4414
# Epoch 5/5
# 18453/18453 [==============================] - 1s 33us/step - loss: 1.0002 - accuracy: 0.3890 - val_loss: 1.0003 - val_accuracy: 0.3514
# Train on 18453 samples, validate on 4613 samples
# Epoch 1/5
# 18453/18453 [==============================] - 1s 58us/step - loss: 1.0003 - accuracy: 0.4044 - val_loss: 1.0001 - val_accuracy: 0.4002
# Epoch 2/5
# 18453/18453 [==============================] - 1s 34us/step - loss: 1.0002 - accuracy: 0.3884 - val_loss: 1.0001 - val_accuracy: 0.3731
# Epoch 3/5
# 18453/18453 [==============================] - 1s 34us/step - loss: 1.0002 - accuracy: 0.3927 - val_loss: 1.0002 - val_accuracy: 0.4414
# Epoch 4/5
# 18453/18453 [==============================] - 1s 34us/step - loss: 1.0002 - accuracy: 0.3986 - val_loss: 1.0002 - val_accuracy: 0.3731
# Epoch 5/5
# 18453/18453 [==============================] - 1s 32us/step - loss: 1.0002 - accuracy: 0.3877 - val_loss: 1.0003 - val_accuracy: 0.3592
# Train on 18453 samples, validate on 4613 samples
# Epoch 1/5
# 18453/18453 [==============================] - 1s 55us/step - loss: 1.0006 - accuracy: 0.3955 - val_loss: 1.0001 - val_accuracy: 0.4414
# Epoch 2/5
# 18453/18453 [==============================] - 1s 34us/step - loss: 1.0001 - accuracy: 0.3893 - val_loss: 1.0002 - val_accuracy: 0.3276
# Epoch 3/5
# 18453/18453 [==============================] - 1s 34us/step - loss: 1.0001 - accuracy: 0.3877 - val_loss: 1.0001 - val_accuracy: 0.4414
# Epoch 4/5
# 18453/18453 [==============================] - 1s 34us/step - loss: 1.0002 - accuracy: 0.3866 - val_loss: 1.0002 - val_accuracy: 0.4414
# Epoch 5/5
# 18453/18453 [==============================] - 1s 34us/step - loss: 1.0002 - accuracy: 0.3877 - val_loss: 1.0001 - val_accuracy: 0.3304
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_5 (LSTM)                (None, 100)               40800
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 41,103
# Trainable params: 41,103
# Non-trainable params: 0
# _________________________________________________________________

# %%
#define the model
model = Sequential()
model.build(input_shape= (1, X_Train.shape[1], X_Train.shape[2]) )
model.add(LSTM(100, dropout=0.5, recurrent_dropout=0.5))
model.add(Dense(3, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=opt,metrics = ['accuracy'])
model.summary()
#fit
history = model.fit(X_Train, y_Train, validation_data=(X_Test, y_Test), epochs=5, batch_size=1)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_6 (LSTM)                (1, 100)                  40800
# _________________________________________________________________
# dense_6 (Dense)              (1, 3)                    303
# =================================================================
# Total params: 41,103
# Trainable params: 41,103
# Non-trainable params: 0
# _________________________________________________________________
# Train on 18452 samples, validate on 4614 samples
# Epoch 1/5
# 18452/18452 [==============================] - 33s 2ms/step - loss: 1.0912 - accuracy: 0.4162 - val_loss: 1.0958 - val_accuracy: 0.4473
# Epoch 2/5
# 18452/18452 [==============================] - 33s 2ms/step - loss: 1.0908 - accuracy: 0.4190 - val_loss: 1.0827 - val_accuracy: 0.4473
# Epoch 3/5
# 18452/18452 [==============================] - 34s 2ms/step - loss: 1.0902 - accuracy: 0.4198 - val_loss: 1.0798 - val_accuracy: 0.4473
# Epoch 4/5
# 18452/18452 [==============================] - 34s 2ms/step - loss: 1.0903 - accuracy: 0.4192 - val_loss: 1.0770 - val_accuracy: 0.4473
# Epoch 5/5
# 18452/18452 [==============================] - 33s 2ms/step - loss: 1.0909 - accuracy: 0.4174 - val_loss: 1.0785 - val_accuracy: 0.4473

# %%
def plot_history(history):
    history_dict = history.history

    loss_values = history_dict['loss']
    val_loss_values = history_dict['val_loss']
    acc = history_dict['accuracy']
    val_acc = history_dict['val_accuracy']

    epochs = [i + 1 for i in history.epoch]

    # Plot the results
    plt.figure(figsize=(12, 3.8))
    plt.subplot(121)
    plt.plot(epochs, loss_values, 'b-', label='Training loss')
    plt.plot(epochs, val_loss_values, 'b.-', label='Val loss')
    plt.xlabel('Epochs', fontsize=12)
    plt.xticks(epochs)
    plt.ylabel('Loss', fontsize=12)
    plt.legend(fontsize=14)
    plt.title('Training and validation loss', fontsize=16)

    plt.subplot(122)
    plt.plot(epochs, acc, 'b-', label='Training accuracy')
    plt.plot(epochs, val_acc, 'b.-', label='Val accuracy')
    plt.xlabel('Epochs', fontsize=12)
    plt.xticks(epochs)
    plt.ylabel('Acc', fontsize=12)
    plt.legend(fontsize=14)
    plt.title('Training and validation acc', fontsize=16)

    plt.show()

# %%
plot_history(history)

# %%
# evaluate the model
_, train_acc = model.evaluate(X_Train, y_Train, verbose=0)
_, test_acc = model.evaluate(X_Test, y_Test, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Train: 0.440, Test: 0.447

# %%
# predict probabilities for test set
yhat_probs = model.predict(X_Test, verbose=0)
# predict crisp classes for test set
yhat_classes = model.predict_classes(X_Test, verbose=0)

# %%
yhat_probs[0:5]
# Out:
# array([[0.2434766, 0.2474892, 0.5090342],
#        [0.2434766, 0.2474892, 0.5090342],
#        [0.2434766, 0.2474892, 0.5090342],
#        [0.2434766, 0.2474892, 0.5090342],
#        [0.2434766, 0.2474892, 0.5090342]], dtype=float32)

# %%
yhat_classes[0:5]
# Out:
# array([2, 2, 2, 2, 2])

# %%
testy_inverse = np.argmax(y_Test, axis=1).reshape(-1,1)

# %%
print(testy_inverse.shape)
y_Test = testy_inverse[:, 0]
y_Test.shape
# Out:
# (4614, 1)
# (4614,)

# %%
# reduce to 1d array
yhat_probs = yhat_probs[:, 0]

# %%
# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_Test, yhat_classes)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(y_Test, yhat_classes,pos_label='positive',average='micro')
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_Test, yhat_classes,pos_label='positive',average='micro')
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_Test, yhat_classes,pos_label='positive',average='micro')
print('F1 score: %f' % f1)
# Out:
# Accuracy: 0.447334
# Precision: 0.447334
# Recall: 0.447334
# F1 score: 0.447334
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1321: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   % (pos_label, average), UserWarning)

# %%
# confusion matrix
matrix = confusion_matrix(y_Test, yhat_classes)
print(matrix)
# Out:
# [[   0    0 1319]
#  [   0    0 1231]
#  [   0    0 2064]]

# %%
y_Test.shape,yhat_classes.shape
# Out:
# ((4614,), (4614,))

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_Test,yhat_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1319
#            1       0.00      0.00      0.00      1231
#            2       0.45      1.00      0.62      2064
#
#     accuracy                           0.45      4614
#    macro avg       0.15      0.33      0.21      4614
# weighted avg       0.20      0.45      0.28      4614
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
