# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas import concat
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import LabelEncoder
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers.recurrent import LSTM
from keras.layers.core import Dense, Activation, Dropout
from keras.layers import Dense, Dropout
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
from sklearn.metrics import *
# Out:
# Using TensorFlow backend.

# %%
data =pd.read_csv("/content/drive/My Drive/Reddit_brexit_period4.csv")
data.head()
# Out:
#    Unnamed: 0  periods  ... polarization_class      Date
# 0       12717        4  ...            Against  08-12-16
# 1       12718        4  ...            Neutral  08-12-16
# 2       12719        4  ...            Against  08-12-16
# 3       12720        4  ...            Against  08-12-16
# 4       12721        4  ...            Neutral  08-12-16
#
# [5 rows x 11 columns]

# %%
from sklearn.preprocessing import LabelEncoder

lb_make = LabelEncoder()
data["Stance"] = lb_make.fit_transform(data["polarization_class"])
data[["polarization_class", "Stance"]].head(10)
# Out:
#   polarization_class  Stance
# 0            Against       0
# 1            Neutral       2
# 2            Against       0
# 3            Against       0
# 4            Neutral       2
# 5            Neutral       2
# 6            Against       0
# 7            Against       0
# 8            Neutral       2
# 9             Brexit       1

# %%
data_to_use = data['Stance'].values
data['polarization_class'].value_counts()
# Out:
# Neutral    674
# Against    407
# Brexit     385
# Name: polarization_class, dtype: int64

# %%
# create X/y pairs
df = data['Stance']
df = concat([df, df.shift(1)], axis=1)
df.dropna(inplace=True)

# %%
values = df.values
y1 = values[:, 1]

# %%
#data preprocessing(scaling)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(values[:,0].reshape(-1, 1))
print(scaled_data)
scaled_data.shape
# Out:
# [[ 0.97398353]
#  [-1.41011985]
#  [-1.41011985]
#  ...
#  [ 0.97398353]
#  [ 0.97398353]
#  [-1.41011985]]
# (1465, 1)

# %%
#y1 = to_categorical(y1)
#y1.shape
#labels = to_categorical(data['LABEL'], num_classes=3)
#do this instead of above
encoder = LabelEncoder()
labels = to_categorical(encoder.fit_transform(values[:, 1]), num_classes=3)

# %%
labels.shape
# Out:
# (1465, 3)

# %%
X_Train, X_Test, y_Train, y_Test = train_test_split(scaled_data,labels, test_size=0.20, random_state=42)

# %%
print(" X Training Set size is",X_Train.shape )
print(" y Training Set size is",y_Train.shape  )
print(" X Test Set size is",X_Test.shape)
print(" y Test Set size is",y_Test.shape )
# Out:
#  X Training Set size is (1172, 1)
#  y Training Set size is (1172, 3)
#  X Test Set size is (293, 1)
#  y Test Set size is (293, 3)

# %%
# convert to LSTM friendly format
X_Train = X_Train.reshape(len(X_Train),1, 1)
X_Test = X_Test.reshape(len(X_Test),1,1)
print(X_Train.shape,X_Test.shape)
# Out:
# (1172, 1, 1) (293, 1, 1)

# %%
scaled_data = scaled_data.reshape(len(scaled_data),1,1)

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
Y_reg = values[:, 1]
X= scaled_data

# %%
from keras.optimizers import SGD, adam, rmsprop
opt = SGD(lr=0.1)
opt_alpha2 = rmsprop(lr =0.0001)
opt_alpha1 = adam(lr=0.01)

# %%
#cross validation -- beware lasts long
cvscores = []
loss_vals = []
val_accs = []
for train, test in kfold.split(X, Y_reg):
  #Turn labels into categorical after the split
  encoder = LabelEncoder()
  Y = to_categorical(encoder.fit_transform(Y_reg), num_classes=3)
  #define the model
  model = Sequential()
  model.add(LSTM(100, dropout=0.5, recurrent_dropout=0.5))
  model.add(Dense(3, activation='softmax'))
  model.compile(loss='categorical_hinge', optimizer= 'adam', metrics=['accuracy'])
  
  #fit the model
  history = model.fit(X[train], Y[train], validation_data=(X[test], Y[test]), epochs=5, batch_size=256)
  #predict
  score = model.evaluate(X[test], Y[test], verbose=0)
  #store values
  loss_vals.append(history.history['val_loss'])
  val_accs.append(history.history['val_accuracy'])
  cvscores.append(score[1])
model.summary()
# Out:
# Train on 1172 samples, validate on 293 samples
# Epoch 1/5
# 1172/1172 [==============================] - 1s 873us/step - loss: 1.0015 - accuracy: 0.3754 - val_loss: 1.0004 - val_accuracy: 0.4573
# Epoch 2/5
# 1172/1172 [==============================] - 0s 50us/step - loss: 1.0006 - accuracy: 0.4556 - val_loss: 1.0007 - val_accuracy: 0.3891
# Epoch 3/5
# 1172/1172 [==============================] - 0s 56us/step - loss: 1.0004 - accuracy: 0.4292 - val_loss: 1.0004 - val_accuracy: 0.3993
# Epoch 4/5
# 1172/1172 [==============================] - 0s 49us/step - loss: 1.0002 - accuracy: 0.4352 - val_loss: 1.0001 - val_accuracy: 0.4369
# Epoch 5/5
# 1172/1172 [==============================] - 0s 50us/step - loss: 1.0004 - accuracy: 0.4181 - val_loss: 1.0002 - val_accuracy: 0.4369
# Train on 1172 samples, validate on 293 samples
# Epoch 1/5
# 1172/1172 [==============================] - 1s 505us/step - loss: 1.0013 - accuracy: 0.4172 - val_loss: 1.0008 - val_accuracy: 0.4608
# Epoch 2/5
# 1172/1172 [==============================] - 0s 50us/step - loss: 1.0008 - accuracy: 0.4445 - val_loss: 1.0003 - val_accuracy: 0.4608
# Epoch 3/5
# 1172/1172 [==============================] - 0s 45us/step - loss: 1.0004 - accuracy: 0.3916 - val_loss: 1.0003 - val_accuracy: 0.3652
# Epoch 4/5
# 1172/1172 [==============================] - 0s 48us/step - loss: 1.0003 - accuracy: 0.4386 - val_loss: 1.0005 - val_accuracy: 0.3720
# Epoch 5/5
# 1172/1172 [==============================] - 0s 52us/step - loss: 1.0002 - accuracy: 0.4445 - val_loss: 1.0003 - val_accuracy: 0.3925
# Train on 1172 samples, validate on 293 samples
# Epoch 1/5
# 1172/1172 [==============================] - 1s 539us/step - loss: 1.0016 - accuracy: 0.3848 - val_loss: 1.0009 - val_accuracy: 0.4608
# Epoch 2/5
# 1172/1172 [==============================] - 0s 49us/step - loss: 1.0007 - accuracy: 0.4599 - val_loss: 1.0006 - val_accuracy: 0.4608
# Epoch 3/5
# 1172/1172 [==============================] - 0s 47us/step - loss: 1.0005 - accuracy: 0.4232 - val_loss: 1.0013 - val_accuracy: 0.3549
# Epoch 4/5
# 1172/1172 [==============================] - 0s 43us/step - loss: 1.0003 - accuracy: 0.4232 - val_loss: 1.0005 - val_accuracy: 0.4266
# Epoch 5/5
# 1172/1172 [==============================] - 0s 48us/step - loss: 1.0003 - accuracy: 0.4599 - val_loss: 1.0003 - val_accuracy: 0.4608
# Train on 1172 samples, validate on 293 samples
# Epoch 1/5
# 1172/1172 [==============================] - 1s 487us/step - loss: 1.0013 - accuracy: 0.3857 - val_loss: 1.0007 - val_accuracy: 0.4608
# Epoch 2/5
# 1172/1172 [==============================] - 0s 47us/step - loss: 1.0011 - accuracy: 0.4078 - val_loss: 1.0004 - val_accuracy: 0.4608
# Epoch 3/5
# 1172/1172 [==============================] - 0s 47us/step - loss: 1.0005 - accuracy: 0.4377 - val_loss: 1.0003 - val_accuracy: 0.4130
# Epoch 4/5
# 1172/1172 [==============================] - 0s 46us/step - loss: 1.0002 - accuracy: 0.4044 - val_loss: 1.0001 - val_accuracy: 0.3652
# Epoch 5/5
# 1172/1172 [==============================] - 0s 50us/step - loss: 1.0002 - accuracy: 0.4215 - val_loss: 1.0001 - val_accuracy: 0.4608
# Train on 1172 samples, validate on 293 samples
# Epoch 1/5
# 1172/1172 [==============================] - 1s 535us/step - loss: 1.0059 - accuracy: 0.3805 - val_loss: 1.0031 - val_accuracy: 0.3379
# Epoch 2/5
# 1172/1172 [==============================] - 0s 51us/step - loss: 1.0019 - accuracy: 0.4266 - val_loss: 1.0013 - val_accuracy: 0.4608
# Epoch 3/5
# 1172/1172 [==============================] - 0s 43us/step - loss: 1.0011 - accuracy: 0.4599 - val_loss: 1.0004 - val_accuracy: 0.4608
# Epoch 4/5
# 1172/1172 [==============================] - 0s 49us/step - loss: 1.0012 - accuracy: 0.4386 - val_loss: 1.0003 - val_accuracy: 0.4096
# Epoch 5/5
# 1172/1172 [==============================] - 0s 54us/step - loss: 1.0009 - accuracy: 0.4386 - val_loss: 1.0001 - val_accuracy: 0.4334
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_5 (LSTM)                (None, 100)               40800
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 41,103
# Trainable params: 41,103
# Non-trainable params: 0
# _________________________________________________________________

# %%
#define the model
model = Sequential()
model.build(input_shape= (1, X_Train.shape[1], X_Train.shape[2]) )
model.add(LSTM(100, dropout=0.5, recurrent_dropout=0.5))
model.add(Dense(3, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=opt,metrics = ['accuracy'])
model.summary()
#fit
history = model.fit(X_Train, y_Train, validation_data=(X_Test, y_Test), epochs=5, batch_size=1)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_6 (LSTM)                (1, 100)                  40800
# _________________________________________________________________
# dense_6 (Dense)              (1, 3)                    303
# =================================================================
# Total params: 41,103
# Trainable params: 41,103
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1172 samples, validate on 293 samples
# Epoch 1/5
# 1172/1172 [==============================] - 3s 3ms/step - loss: 1.0847 - accuracy: 0.4428 - val_loss: 1.1105 - val_accuracy: 0.4573
# Epoch 2/5
# 1172/1172 [==============================] - 3s 2ms/step - loss: 1.0854 - accuracy: 0.4343 - val_loss: 1.0886 - val_accuracy: 0.4573
# Epoch 3/5
# 1172/1172 [==============================] - 3s 2ms/step - loss: 1.0800 - accuracy: 0.4428 - val_loss: 1.0768 - val_accuracy: 0.4573
# Epoch 4/5
# 1172/1172 [==============================] - 3s 2ms/step - loss: 1.0835 - accuracy: 0.4369 - val_loss: 1.0891 - val_accuracy: 0.3379
# Epoch 5/5
# 1172/1172 [==============================] - 3s 2ms/step - loss: 1.0787 - accuracy: 0.4539 - val_loss: 1.1166 - val_accuracy: 0.3003

# %%
def plot_history(history):
    history_dict = history.history

    loss_values = history_dict['loss']
    val_loss_values = history_dict['val_loss']
    acc = history_dict['accuracy']
    val_acc = history_dict['val_accuracy']

    epochs = [i + 1 for i in history.epoch]

    # Plot the results
    plt.figure(figsize=(12, 3.8))
    plt.subplot(121)
    plt.plot(epochs, loss_values, 'b-', label='Training loss')
    plt.plot(epochs, val_loss_values, 'b.-', label='Val loss')
    plt.xlabel('Epochs', fontsize=12)
    plt.xticks(epochs)
    plt.ylabel('Loss', fontsize=12)
    plt.legend(fontsize=14)
    plt.title('Training and validation loss', fontsize=16)

    plt.subplot(122)
    plt.plot(epochs, acc, 'b-', label='Training accuracy')
    plt.plot(epochs, val_acc, 'b.-', label='Val accuracy')
    plt.xlabel('Epochs', fontsize=12)
    plt.xticks(epochs)
    plt.ylabel('Acc', fontsize=12)
    plt.legend(fontsize=14)
    plt.title('Training and validation acc', fontsize=16)

    plt.show()

# %%
plot_history(history)

# %%
# evaluate the model
_, train_acc = model.evaluate(X_Train, y_Train, verbose=0)
_, test_acc = model.evaluate(X_Test, y_Test, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Train: 0.328, Test: 0.341

# %%
# predict probabilities for test set
yhat_probs = model.predict(X_Test, verbose=0)
# predict crisp classes for test set
yhat_classes = model.predict_classes(X_Test, verbose=0)

# %%
yhat_probs[0:5]
# Out:
# array([[0.2711349 , 0.39165646, 0.33720854],
#        [0.2711349 , 0.39165646, 0.33720854],
#        [0.2711349 , 0.39165646, 0.33720854],
#        [0.2711349 , 0.39165646, 0.33720854],
#        [0.2711349 , 0.39165646, 0.33720854]], dtype=float32)

# %%
yhat_classes[0:5]
# Out:
# array([1, 1, 1, 1, 1])

# %%
testy_inverse = np.argmax(y_Test, axis=1).reshape(-1,1)

# %%
print(testy_inverse.shape)
y_Test = testy_inverse[:, 0]
y_Test.shape
# Out:
# (293, 1)
# (293,)

# %%
# reduce to 1d array
yhat_probs = yhat_probs[:, 0]

# %%
# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_Test, yhat_classes)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(y_Test, yhat_classes,pos_label='positive',average='micro')
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_Test, yhat_classes,pos_label='positive',average='micro')
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_Test, yhat_classes,pos_label='positive',average='micro')
print('F1 score: %f' % f1)
# Out:
# Accuracy: 0.341297
# Precision: 0.341297
# Recall: 0.341297
# F1 score: 0.341297
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1321: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   % (pos_label, average), UserWarning)

# %%
# confusion matrix
matrix = confusion_matrix(y_Test, yhat_classes)
print(matrix)
# Out:
# [[ 0 48 41]
#  [ 0 39 31]
#  [ 0 73 61]]

# %%
y_Test.shape,yhat_classes.shape
# Out:
# ((293,), (293,))

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_Test,yhat_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        89
#            1       0.24      0.56      0.34        70
#            2       0.46      0.46      0.46       134
#
#     accuracy                           0.34       293
#    macro avg       0.23      0.34      0.27       293
# weighted avg       0.27      0.34      0.29       293
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
